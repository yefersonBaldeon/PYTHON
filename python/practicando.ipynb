# %%
import pandas as pd
import numpy as np

# %%
one =pd.read_csv("https://raw.githubusercontent.com/yefersonBaldeon/probando_csv/main/dataset.csv")
one
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
one.shape
# Out:
# (480, 17)

# %%
one["gender"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
len(one[one["gender"]=="M"])
# Out:
# 305

# %%
len(one[one["gender"]=="F"])
# Out:
# 175

# %%
one.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   480.000000        480.000000         480.000000  480.000000
# mean     46.775000         54.797917          37.918750   43.283333
# std      30.779223         33.080007          26.611244   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      15.750000         20.000000          14.000000   20.000000
# 50%      50.000000         65.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %%
one
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
one.columns
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
one.columns[3]
# Out:
# 'StageID'

# %%
one[one.columns[3]].unique()
# Out:
# array(['lowerlevel', 'MiddleSchool', 'HighSchool'], dtype=object)

# %%
one
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
a=pd.get_dummies(one["gender"])
a
# Out:
#      F  M
# 0    0  1
# 1    0  1
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 475  1  0
# 476  1  0
# 477  1  0
# 478  1  0
# 479  1  0
#
# [480 rows x 2 columns]

# %%
# one=one.join(a)

# %%
one
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
one.drop("gender",axis=1,inplace=True)

# %%
one
# Out:
#     NationalITy PlaceofBirth       StageID GradeID SectionID      Topic  \
# 0            KW       KuwaIT    lowerlevel    G-04         A         IT
# 1            KW       KuwaIT    lowerlevel    G-04         A         IT
# 2            KW       KuwaIT    lowerlevel    G-04         A         IT
# 3            KW       KuwaIT    lowerlevel    G-04         A         IT
# 4            KW       KuwaIT    lowerlevel    G-04         A         IT
# ..          ...          ...           ...     ...       ...        ...
# 475      Jordan       Jordan  MiddleSchool    G-08         A  Chemistry
# 476      Jordan       Jordan  MiddleSchool    G-08         A    Geology
# 477      Jordan       Jordan  MiddleSchool    G-08         A    Geology
# 478      Jordan       Jordan  MiddleSchool    G-08         A    History
# 479      Jordan       Jordan  MiddleSchool    G-08         A    History
#
#     Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# ...

# %%
one.groupby(one.columns[3]).mean()
# Out:
#          raisedhands  VisITedResources  AnnouncementsView  Discussion  \
# GradeID
# G-02       36.530612         51.476190          28.122449   34.374150
# G-04       46.729167         51.687500          43.125000   51.125000
# G-05       12.000000         14.000000          12.666667   30.000000
# G-06       61.625000         54.937500          47.000000   45.343750
# G-07       47.722772         53.811881          37.811881   48.485149
# G-08       56.784483         63.370690          46.715517   43.784483
# G-09       21.600000         46.000000          27.000000   58.000000
# G-10       36.750000         44.500000          31.250000   33.500000
# G-11       58.307692         62.307692          52.384615   55.692308
# G-12       37.363636         41.000000          25.090909   54.909091
#
#                 F         M
# GradeID
# G-02     0.380952  0.619048
# G-04     0.416667  0.583333
# G-05     0.333333  0.666667
# G-06     0.468750  0.531250
# G-07     0.316832  0.683168
# ...

# %%
df=pd.read_csv("https://raw.githubusercontent.com/joanby/python-ml-course/master/datasets/titanic/titanic3.csv")

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.shape
# Out:
# (1309, 14)

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
a=df.isnull()
a
# Out:
#       pclass  survived   name    sex    age  sibsp  parch  ticket   fare  \
# 0      False     False  False  False  False  False  False   False  False
# 1      False     False  False  False  False  False  False   False  False
# 2      False     False  False  False  False  False  False   False  False
# 3      False     False  False  False  False  False  False   False  False
# 4      False     False  False  False  False  False  False   False  False
# ...      ...       ...    ...    ...    ...    ...    ...     ...    ...
# 1304   False     False  False  False  False  False  False   False  False
# 1305   False     False  False  False   True  False  False   False  False
# 1306   False     False  False  False  False  False  False   False  False
# 1307   False     False  False  False  False  False  False   False  False
# 1308   False     False  False  False  False  False  False   False  False
#
#       cabin  embarked   boat   body  home.dest
# ...

# %%
df.isnull()["age"]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304    False
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: age, Length: 1309, dtype: bool

# %%
df1=df.iloc[:,:]

# %%
df.isnull()[["age"]]
# Out:
#         age
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 1304  False
# 1305   True
# 1306  False
# 1307  False
# 1308  False
#
# [1309 rows x 1 columns]

# %%
df1["nuevo22"]=df.isnull()[["age"]]

# %%
df1[df1["nuevo"]==True]
# Out:
#       pclass  survived                                               name  \
# 15         1         0                                Baumann, Mr. John D
# 37         1         1      Bradley, Mr. George ("George Arthur Brayton")
# 40         1         0                          Brewe, Dr. Arthur Jackson
# 46         1         0                              Cairns, Mr. Alexander
# 59         1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# ...      ...       ...                                                ...
# 1293       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1305       3         0                              Zabour, Miss. Thamine
#
#          sex  age  sibsp  parch      ticket     fare cabin embarked boat  \
# ...

# %%
a
# Out:
#       pclass  survived   name    sex    age  sibsp  parch  ticket   fare  \
# 0      False     False  False  False  False  False  False   False  False
# 1      False     False  False  False  False  False  False   False  False
# 2      False     False  False  False  False  False  False   False  False
# 3      False     False  False  False  False  False  False   False  False
# 4      False     False  False  False  False  False  False   False  False
# ...      ...       ...    ...    ...    ...    ...    ...     ...    ...
# 1304   False     False  False  False  False  False  False   False  False
# 1305   False     False  False  False   True  False  False   False  False
# 1306   False     False  False  False  False  False  False   False  False
# 1307   False     False  False  False  False  False  False   False  False
# 1308   False     False  False  False  False  False  False   False  False
#
#       cabin  embarked   boat   body  home.dest
# ...

# %%
a[a["age"]==True]
# Out:
#       pclass  survived   name    sex   age  sibsp  parch  ticket   fare  \
# 15     False     False  False  False  True  False  False   False  False
# 37     False     False  False  False  True  False  False   False  False
# 40     False     False  False  False  True  False  False   False  False
# 46     False     False  False  False  True  False  False   False  False
# 59     False     False  False  False  True  False  False   False  False
# ...      ...       ...    ...    ...   ...    ...    ...     ...    ...
# 1293   False     False  False  False  True  False  False   False  False
# 1297   False     False  False  False  True  False  False   False  False
# 1302   False     False  False  False  True  False  False   False  False
# 1303   False     False  False  False  True  False  False   False  False
# 1305   False     False  False  False  True  False  False   False  False
#
#       cabin  embarked   boat  body  home.dest
# 15     True     False   True  True      False
# ...
